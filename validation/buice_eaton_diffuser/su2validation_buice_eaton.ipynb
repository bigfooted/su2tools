# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon
import pandas as pd

# read experimental data
#col_list = ["location", "velocity"]
# we have a number of spaces as delimiter, not just one space, so we need regexp to deal with it.
dfmin6 = pd.read_csv("/home/nijso/Downloads/stanford_channel/m__U%.x-6",delimiter=r"\s+")
df03 = pd.read_csv("/home/nijso/Downloads/stanford_channel/m__U%.x03",delimiter=r"\s+")
df06 = pd.read_csv("/home/nijso/Downloads/stanford_channel/m__U%.x06",delimiter=r"\s+")
df14 = pd.read_csv("/home/nijso/Downloads/stanford_channel/m__U%.x14",delimiter=r"\s+")
df20 = pd.read_csv("/home/nijso/Downloads/stanford_channel/m__U%.x20",delimiter=r"\s+")
df30 = pd.read_csv("/home/nijso/Downloads/stanford_channel/m__U%.x30",delimiter=r"\s+")
df40 = pd.read_csv("/home/nijso/Downloads/stanford_channel/m__U%.x40",delimiter=r"\s+")
df60 = pd.read_csv("/home/nijso/Downloads/stanford_channel/m__U%.x60",delimiter=r"\s+")
df74 = pd.read_csv("/home/nijso/Downloads/stanford_channel/m__U%.x74",delimiter=r"\s+")



pts_top = np.array([[-8.0,4.7], [70,4.7], [70,5.7],[-8,5.7]])
pts_bottom = np.array([[-8.0,3.7], [0,3.7], [21,0],[70,0],[70,-5],[-8.0,-5]])

p1 = Polygon(pts_top, closed=True,fc='grey',ec='black')
p2 = Polygon(pts_bottom, closed=True,fc='grey',ec='black')

#ax = plt.gca()
#ax.add_patch(p)
#ax.set_xlim(1,7)
#ax.set_ylim(1,8)
#plt.show()

# define data

H = [ 2 , 2.5, 3, 3.5, 4, 4.5, 5]
U = [ 0 , 8,10,12, 14, 16, 0]

fig = plt.figure(figsize=(25,20))
ax = fig.add_subplot(111)
#ax.invert_yaxis()

#ax.ylim(0,50)
#ax.plot(U, H, 'go--')
Uc = 10

ax.plot(-5.87+dfmin6['velocity']*Uc,dfmin6['location'],'-o')
ax.plot(2.59+df03['velocity']*Uc,df03['location'],'-o')
ax.plot(5.98+df06['velocity']*Uc,df06['location'],'-o')
ax.plot(13.56+df14['velocity']*Uc,df14['location'],'-o')
ax.plot(20.32+df20['velocity']*Uc,df20['location'],'-o')
ax.plot(30.48+df30['velocity']*Uc,df30['location'],'-o')
ax.plot(40+df40['velocity']*Uc,df40['location'],'-o')
ax.plot(60+df60['velocity']*Uc,df60['location'],'-o')
ax.plot(74+df74['velocity']*Uc,df74['location'],'-o')


ax.add_patch(p1)
ax.add_patch(p2)

#ax.xaxis.tick_bottom()

ax.set_ylabel('H')
ax.set_ylim(-0.2, 4.9)
ax.set_xlim(-10, 35)
ax.set_xlabel('Vel')

plt.show()

# %%
-6+dfmin6*20
# Out:
#     location  velocity
# 0     68.000     -6.00
# 1     68.136      1.88
# 2     68.188      3.50
# 3     68.256      5.24
# 4     68.340      6.84
# 5     68.446      8.12
# 6     68.580      9.14
# 7     68.746      9.92
# 8     68.956     10.50
# 9     69.218     11.06
# 10    69.548     11.58
# 11    69.962     12.14
# 12    70.482     12.74
# 13    71.136     13.38
# 14    71.954     14.00
# 15    72.982     15.00
# 16    74.272     15.60
# 17    75.892     16.40
# 18    77.926     16.80

# %%
df
# Out:
#       location     velocity
# 0      3.25E+00    8.66E-02
# 1      3.32E+00    3.20E-01
# 2     3.39E+00    4.14E-01
# 3     3.45E+00    5.06E-01
# 4     3.52E+00    5.98E-01
# 5     3.59E+00    6.76E-01
# 6     3.66E+00    7.35E-01
# 7     3.73E+00    7.82E-01
# 8     3.80E+00    8.19E-01
# 9     3.87E+00    8.50E-01
# 10    3.93E+00    8.72E-01
# 11    4.00E+00    8.79E-01
# 12    4.07E+00    8.75E-01
# 13    4.14E+00    8.58E-01
# 14    4.21E+00    8.30E-01
# 15    4.28E+00    7.96E-01
# 16    4.34E+00    7.55E-01
# 17    4.41E+00    7.06E-01
# 18   4.48E+00    6.48E-01
# 19   4.55E+00    5.79E-01

# %%
df['location']
# Out:
# 0     3.25
# 1     3.32
# 2     3.39
# 3     3.45
# 4     3.52
# 5     3.59
# 6     3.66
# 7     3.73
# 8     3.80
# 9     3.87
# 10    3.93
# 11    4.00
# 12    4.07
# 13    4.14
# 14    4.21
# 15    4.28
# 16    4.34
# 17    4.41
# 18    4.48
# 19    4.55
# Name: location, dtype: float64
